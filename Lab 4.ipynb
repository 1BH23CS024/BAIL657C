# %% [markdown]
# **Lab 4**
#
# Use word embeddings to improve prompts for Generative AI model. Retrieve similar words using word embeddings. Use the similar words to enrich a Gen AI prompt. Use the AI model to generate responses for the original and enriched prompts. Compare the outputs in terms of detail and relevance.

# %%
# !pip install -q gensim transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 22.0 MB/s eta 0:00:00

# %%
import gensim.downloader as api
from transformers import pipeline

# %%
model = api.load("glove-wiki-gigaword-100")

# %%
orig_prompt = "Who is king?"

# %%
enriched = []
for word in orig_prompt.split():
    if word.lower() in model:
        for w, score in model.most_similar(word.lower(), topn=2):
            enriched.append(w)
enr_prompt = orig_prompt + " " + " ".join(enriched)

print("Original Prompt:", orig_prompt)
print("Enriched Prompt:", enr_prompt)
# Out:
# Original Prompt: Who is king?
# Enriched Prompt: Who is king? whom he this it

# %%
generator = pipeline("text-generation", model="distilgpt2")
orig_out = generator(orig_prompt, max_length=100)[0]["generated_text"]
enr_out = generator(enr_prompt, max_length=100)[0]["generated_text"]
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]

# %%
print("Original Response:\n\n", orig_out)
print("\nResponse Length: ", len(orig_out.split()))
# Out:
# Original Response:
#
# ...

# %%
print("Enriched Response:\n\n", enr_out)
print("\nResponse Length: ", len(enr_out.split()))
# Out:
# Enriched Response:
#
#  Who is king? whom he this it is, and who he will be.›
#
# The kingdom of Israel is just one of many things in Israel: it is a nation of people. It is the first nation in the world—even as a whole, at the very least, and the only one that ever has been made to be the king of Israel.
# When the king of Israel came to Israel in 1768, he was a son of a king who had once been king of this country. He took the throne of Israel and, in 1770, he was the first king of Israel to be the first king of Israel.
# The kingdom of Israel was a people of people. It was the first nation in the world—even as a whole, at the very least, and the only one that ever has been made to be the king of Israel.
# In the early 1770s, and since then, Israel has been part of the world. The kingdom of Israel is a land of people, and it is the only one that ever has been made to be the king of Israel.
# In the early 1770s, and since then, Israel has been part of the world.
# ...

# %%
w1 = [w for w in orig_prompt.lower().split() if w in model]
w2 = [w for w in orig_out.lower().split() if w in model]
w3 = [w for w in enr_out.lower().split() if w in model]

print("Original Relevance:", model.n_similarity(w1, w2))
print("Enriched Relevance:", model.n_similarity(w1, w3))
# Out:
# Original Relevance: 0.8318287
# Enriched Relevance: 0.8974097
