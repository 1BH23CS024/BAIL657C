# %% [markdown]
# **Lab 8**
#
# Install langchain, cohere, langchain-community. Get the API key. Load a text document from your Google Drive. Create a prompt template to display the output in a particular manner.

# %%
# !pip install langchain-community langchain-core langchain-cohere cohere
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.3/334.3 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 29.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
import os
from langchain_community.document_loaders import TextLoader
from langchain_core.prompts import PromptTemplate
from langchain_cohere import ChatCohere

# %%
os.environ["COHERE_API_KEY"] = "YOUR_COHERE_API_KEY"
# EXAMPLE: os.environ["COHERE_API_KEY"] = "ghUIJopNUmxOZMyaLdtlOpXD4HCNQOOZbGSEFwFE"
# Note: The above is fake and does not work. Generate your own at https://cohere.com

file_path = "FILE_PATH_TO_INPUT_TEXT"
# EXAMPLE: file_path = "/content/drive/MyDrive/industrial_revolution.txt"
# Step 1: Go to 'Files' tab from the sidebar in Colab
# Step 2: Mount Google Drive by clicking the folder icon (3rd from left)

# %%
text = TextLoader(file_path).load()[0].page_content
chain = PromptTemplate.from_template(f"Summarize:\n{text}") | ChatCohere()

print(chain.invoke({"text": text}).content)
# Out:
# The Industrial Revolution, spanning the 18th to 19th centuries, transformed agrarian, rural societies in Europe and America into industrial and urban ones. It shifted manufacturing from home-based, manual production to factory-based mass production using powered machinery. Key drivers included advancements in the iron and textile industries, the steam engine, and improvements in transportation, communication, and banking. While it increased the availability of goods and raised living standards for some, it also led to harsh working and living conditions for the poor and working classes.
